# %%
from simulator_oop import BoidSimulator, SimParams, SimSaverLoader 
import tester
import viewer

# %% [markdown]
# # Lumburn Et Al Results

# %%
path = ['tests/super_long/']
datas = SimSaverLoader.find_npzs(path)
kr = tester.KernelReservoir(200,datas[0],datas[1])

kr.get_prediction(1)
kr.plot_results()
# Out:
# Loaded 2 run(s)
# ...
# Vectorized: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]

# %%
path = ['tests/super_long/']
datas = SimSaverLoader.find_npzs(path)
pa = tester.PropertyAnalysis(datas)
pa.simulation_noise()
# Out:
# Loaded 2 run(s)
# array([[[ 0.39400871,  0.01459733, -0.0715178 , ...,  0.48806182,
#           0.36544545,  0.28731961],
#         [ 0.47257835,  0.09396352,  3.9284822 , ...,  0.57365297,
#           0.33569656,  4.27955744],
#         [ 0.631148  ,  0.17872958,  7.9284822 , ...,  0.6902241 ,
#          -3.66430203,  5.82855665],
#         ...,
#         [ 2.88094704,  0.48863976, -1.92672031, ...,  0.88568739,
#           3.83669131, -0.21068055],
#         [ 2.84380498,  0.45509121, -1.85710291, ...,  0.88827207,
#           3.20310109,  0.12923378],
#         [ 2.81259825,  0.38091622, -1.56033618, ...,  0.87520813,
#           0.9728917 , -0.65319685]],
#
#        [[-0.39400871, -0.01459733,  0.0715178 , ..., -0.48806182,
#          -0.36544545, -0.28731961],
#         [-0.47257835, -0.09396352, -3.9284822 , ..., -0.57365297,
#          -0.33569656, -4.27955744],
#         [-0.631148  , -0.17872958, -7.9284822 , ..., -0.6902241 ,
#           3.66430203, -5.82855665],
# ...
